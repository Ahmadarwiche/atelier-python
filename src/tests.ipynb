# %% [markdown]
# ### Définition
# Les tests sont un élément essentiel à tout langage informatique si on veut lui donner un peu de complexité car ils
# permettent à l’ordinateur de prendre des décisions. Pour cela, Python utilise l’instruction if ainsi qu’une comparaison
# que nous avons abordée au chapitre précédent. Voici un premier exemple :

# %%
x = 2 
if x == 2:
    print("Le test est vrai")
# Out:
# Le test est vrai

# %%
x = 2 
if x == "chat":
    print("Le test est vrai")

# %% [markdown]
# Il y a plusieurs remarques à faire concernant ces deux exemples :
# - Dans le premier exemple, l’instruction print("Le test est vrai !") est exécutée, car le test est vrai. Dans le
# second exemple, le test est faux et rien n’est affiché.
# - Les blocs d’instructions dans les tests doivent forcément être indentés comme pour les boucles for et while.
# L’indentation indique la portée des instructions à exécuter si le test est vrai.
# - Comme avec les boucles for et while, la ligne qui contient l’instruction if se termine par le caractère deux-points
# « : ».

# %% [markdown]
# ### Tests à plusieurs cas
# Parfois, il est pratique de tester si la condition est vraie ou si elle est fausse dans une même instruction if. Plutôt
# que d’utiliser deux instructions if, on peut se servir des instructions if et else :

# %%
x = 2
if x != 2:
    print("Le test est vrai !")
else:
    print("Le test est faux !")
# Out:
# Le test est faux !

# %% [markdown]
# On peut utiliser une série de tests dans la même instruction if, notamment pour tester plusieurs valeurs d’une même
# variable.

# %%
x = 2
if x == 1:
    print("Le test est faux !")
elif x == 2:
    print("Le test est vrai")
else:
    print("Le test est faux !")
# Out:
# Le test est vrai

# %% [markdown]
# Dans cet exemple, Python teste la première condition puis, si et seulement si elle est fausse, teste la deuxième et ainsi
# de suite…

# %% [markdown]
# ###  Importance de l’indentation
# De nouveau, faites bien attention à l’indentation! Vous devez être très rigoureux sur ce point. Pour vous en convaincre,
# exécutez ces deux exemples de code :

# %%
nombres = [4, 5, 6]
for nb in nombres:
    if nb == 5:
        print("Le test est vrai")
        print(f"car la variable nb vaut {nb}")
# Out:
# Le test est vrai
# car la variable nb vaut 5

# %%
nombres = [4, 5, 6]
for nb in nombres:
    if nb == 5:
        print("Le test est vrai")
    print(f"car la variable nb vaut {nb}")
# Out:
# car la variable nb vaut 4
# Le test est vrai
# car la variable nb vaut 5
# car la variable nb vaut 6

# %% [markdown]
# Les deux codes pourtant très similaires produisent des résultats très différents. Si vous observez avec attention
# l’indentation des instructions sur la ligne 5, vous remarquerez que dans le code 1, l’instruction est indentée deux fois,
# ce qui signifie qu’elle appartient au bloc d’instructions du test if. Dans le code 2, l’instruction de la ligne 5 n’est
# indentée qu’une seule fois, ce qui fait qu’elle n’appartient plus au bloc d’instructions du test if, d’où l’affichage de
# car la variable nb vaut xx pour toutes les valeurs de nb.

# %% [markdown]
# ### Tests multiples
# Les tests multiples permettent de tester plusieurs conditions en même temps en utilisant des opérateurs booléens. Les
# deux opérateurs les plus couramment utilisés sont OU et ET. Voici un petit rappel sur le fonctionnement de l’opérateur
# OU :
# ![image.png](attachment:image.png)
#
# En Python, on utilise le mot réservé and pour l’opérateur ET et le mot réservé or pour l’opérateur OU. Respectez
# bien la casse des opérateurs and et or qui, en Python, s’écrivent en minuscule. En voici un exemple d’utilisation :

# %%
x = 2
y = 2
if x == 2 and y == 2:
    print("le test est vrai")
# Out:
# le test est vrai

# %% [markdown]
# ### Instructions break et continue
# Ces deux instructions modifient le comportement d’une boucle (for ou while) avec un test. Ainsi, l’instruction
# *break* stoppe la boucle en cours :

# %%
for nombre in range(4):
    if nombre > 1:
        break
    print(nombre)
# Out:
# 0
# 1

# %% [markdown]
# L’instruction *continue* saute à l’itération suivante, sans exécuter la suite du bloc d’instructions de la boucle :

# %%
for nombre in range(4):
    if nombre == 1:
        continue
    print(nombre)
# Out:
# 0
# 2
# 3

# %% [markdown]
# ### Tests de valeur sur des floats
# Lorsque l’on souhaite tester la valeur d’une variable de type float, le premier réflexe serait d’utiliser l’opérateur d’égalité
# comme :

# %%
1/10 == 0.1
# Out:
# True

# %% [markdown]
# Toutefois, nous vous le déconseillons formellement. Pourquoi? Python stocke les valeurs numériques des floats sous
# forme de nombres flottants (d’où leur nom), et cela mène à certaines limitations. Observez l’exemple suivant :

# %%
(3 - 2.7) == 0.3
# Out:
# False

# %%
#car
3 - 2.7
# Out:
# 0.2999999999999998

# %% [markdown]
# Ce problème ne vient pas de Python, mais plutôt de la manière dont un ordinateur traite les nombres flottants
# (comme un rapport de nombres binaires). Ainsi certaines valeurs de float ne peuvent être qu’approchées. Pour ces raisons, il ne faut surtout pas utiliser l’opérateur == pour tester si un float est égal à une certaine valeur, car
# cet opérateur correspond à une égalité stricte. La bonne pratique est de vérifier si un float est compris dans un intervalle
# avec une certaine précision.
# Une manière pour tester la valeur d’un float, apparue en Python 3.5, est d’utiliser la fonction *math.isclose()* :

# %%
import math
var = 3.0 - 2.7
math.isclose(var, 0.3, abs_tol=1e-5)
True
# Out:
# True

# %% [markdown]
# Cette fonction prend en argument les deux floats à comparer, ainsi que l’argument par mot-clé abs_tol correspondant
# à la précision souhaitée. Nous vous conseillons de toujours préciser cet argument abs_tol.
